# %% [markdown]
# #Program 1:
#
# 1. Class & objects
#
# 2. Assign Attributes using constructor and self variables
#
# 3. Using Assertion, defining method

# %%
class class_name():
  pass
class1 = class_name()   #<---- Object Created

# %%
class elect_items:
  def __init__(self,name,price,quantity):   #<----- Constructor using self(object) variables
    self.name = name
    self.price = price
    self.quantity = quantity
item_1 = elect_items("Cable","540","80 Mtrs")
item_2 = elect_items("Clamp Multimeter","540","1 Nos")
item_3 = elect_items("LED 40W","540","12 Nos")
item_4 = elect_items("Optical Fiber","540","80 Mtr")
item_5 = elect_items("Socket 6A/16A","540","10 Nos")

for item in [item_1,item_2,item_3,item_4,item_5]:
  print(f"Item name : {item.name}\nItem price : {item.price}\nItem quantity : {item.quantity}\n")
# Out:
# Item name : Cable
# Item price : 540
# Item quantity : 80 Mtrs
#
# Item name : Clamp Multimeter
# Item price : 540
# Item quantity : 1 Nos
#
# Item name : LED 40W
# Item price : 540
# Item quantity : 12 Nos
#
# Item name : Optical Fiber
# Item price : 540
# Item quantity : 80 Mtr
#
# Item name : Socket 6A/16A
# Item price : 540
# Item quantity : 10 Nos

# %%
class elect_items:
  m = []
  def __init__(self,name,price,quantity):   #<----- Constructor using self(object) variables
    self.name = name
    self.price = price
    self.quantity = quantity
    elect_items.m.append(self)
  def total_price(self):
    return self.price * self.quantity
  def __repr__(self):
    return print(f"Item name : {self.name}\nItem Total price : {self.total_price}\nItem quantity : {self.quantity}\n")
print(elect_items.m)
item_1 = elect_items("Cable",230,80)
item_2 = elect_items("Clamp Multimeter",930,1)
item_3 = elect_items("LED 40W",240,12)
item_4 = elect_items("Optical Fiber",280,80)
item_5 = elect_items("Socket 6A/16A",45,10)


for item in elect_items.m:
    print(item)
# Out:
# []
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipython-input-356502267.py in <cell line: 0>()
#      19
#      20 for item in elect_items.m:
# ---> 21     print(item)
#
# /tmp/ipython-input-356502267.py in __repr__(self)
#       9     return self.price * self.quantity
#      10   def __repr__(self):
# ---> 11     return print(f"Item name : {self.name}\nItem Total price : {self.total_price}\nItem quantity : {self.quantity}\n")
#      12 print(elect_items.m)
#      13 item_1 = elect_items("Cable",230,80)
#
# ... last 1 frames repeated, from the frame below ...
#
# /tmp/ipython-input-356502267.py in __repr__(self)
#       9     return self.price * self.quantity
#      10   def __repr__(self):
# ---> 11     return print(f"Item name : {self.name}\nItem Total price : {self.total_price}\nItem quantity : {self.quantity}\n")
#      12 print(elect_items.m)
# ...
